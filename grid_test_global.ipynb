# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline  

import modeltools.grid
import matplotlib.pyplot
import netCDF4
gridg=modeltools.grid.Proj4Grid("+proj=latlong",
                              0,-90,.125,.125,2880,1440)
#figure=grid1.plotgrid(2)
#matplotlib.pyplot.show()
figure=gridg.plotgrid()
matplotlib.pyplot.show()
gridg.save_to_scrip("globalatm.nc",None)
# Out:
# DEBUG:root:Initialized P-grid using projection +proj=latlong
# DEBUG:root:Lower left corner lon/lat of grid: (0,-90)
# DEBUG:root:Grid spacing in projection coords: (0.125,0.125)
# DEBUG:root:Number of grid Nodes in x/y      : ( 2880, 1440)
# DEBUG:root:Min   x projection coordinate = -0.125
# DEBUG:root:Max   x projection coordinate = 360
# DEBUG:root:Min   y projection coordinate = -90.1
# DEBUG:root:Max   y projection coordinate = 90
# DEBUG:root:Min lon = -0.125
# DEBUG:root:Max lon = 360
# DEBUG:root:Min lat = -90.1
# DEBUG:root:Max lat = 90
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# testlon, testlat: 0.125 -89.875
# 39960000.0 19980000.0
# 180.0 0.0
# (11, 11) (10, 10)
# 0.0
# [-0.0625  0.0625  0.0625 -0.0625]
# -90.0
# [-90.0625 -90.0625 -89.9375 -89.9375]
