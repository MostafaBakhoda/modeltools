# %%
import abfile
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_fld(vname,tst1,tst2) :
    f, (ax1, ax2,ax3) = plt.subplots(1, 3, figsize=(15, 5))
    P=ax1.pcolormesh(tst1[vname]) ; plt.colorbar(P,ax=ax1); ax1.set_title(vname); 
    P=ax2.pcolormesh(tst2[vname]) ; plt.colorbar(P,ax=ax2); ax2.set_title(vname); 
    P=ax3.pcolormesh(tst2[vname]-tst1[vname]) ; plt.colorbar(P,ax=ax3); ax3.set_title(vname); 

tmp1=abfile.ABFileGrid("tp5.regional.grid","r")
tmp2=abfile.ABFileGrid("regional.grid","r")

tst1={}
tst2={}

for i in sorted(tmp1.fieldnames) :
    tst1[i]=tmp1.read_field(i);
    tst2[i]=tmp2.read_field(i);
    print "Variable %s, max abs diff=%14.6g"%(i,numpy.abs(tst1[i]-tst2[i]).max())
tmp1.close()
tmp2.close()
    
plot_fld("cori",tst1,tst2)
plot_fld("plat",tst1,tst2)
plot_fld("pang",tst1,tst2)
plot_fld("pasp",tst1,tst2)
plot_fld("scpx",tst1,tst2)
# Out:
# Variable cori, max abs diff=   3.98373e-07
# Variable pang, max abs diff=      0.694526
# Variable pasp, max abs diff=    7.4625e-05
# Variable plat, max abs diff=             0
# Variable plon, max abs diff=             0
# Variable qlat, max abs diff=             0
# Variable qlon, max abs diff=             0
# Variable scpx, max abs diff=      0.421387
# Variable scpy, max abs diff=      0.501953
# Variable scqx, max abs diff=      0.421387
# Variable scqy, max abs diff=      0.501465
# Variable scux, max abs diff=      0.421875
# Variable scuy, max abs diff=      0.501465
# Variable scvx, max abs diff=      0.420898
# Variable scvy, max abs diff=      0.500977
# Variable ulat, max abs diff=             0
# Variable ulon, max abs diff=             0
# Variable vlat, max abs diff=             0
# Variable vlon, max abs diff=             0
