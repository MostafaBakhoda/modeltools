# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline  

import modeltools.hycom.io
import matplotlib.pyplot
import modeltools.bathy
import modeltools.hycom.io
import numpy

f = modeltools.hycom.io.AFile(1350,1150,"/work/users/knutali/hycom/TP5a0.05/relax/phc/saln_sig0_m02.a","r")
fld=f.zaiord_a(0,5)
figure = matplotlib.pyplot.figure(figsize=(8,8))
ax=figure.add_subplot(111)
P=matplotlib.pyplot.pcolormesh(fld)
P.set_clim(33,36)
matplotlib.pyplot.show()


print fld
# Out:
# DEBUG:root:Endianness set to big
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.143720388412 38.6066055298
# [[33.10599899291992 33.10554122924805 33.10506057739258 ...,
#   35.64497756958008 35.71962356567383 35.802337646484375]
#  [33.10689926147461 33.1064567565918 33.10597229003906 ...,
#   35.679603576660156 35.75637435913086 35.84093475341797]
#  [33.10786056518555 33.10741424560547 33.106910705566406 ...,
#   35.71604919433594 35.7947998046875 35.88107681274414]
#  ...,
#  [32.99016571044922 32.992820739746094 32.99549102783203 ...,
#   34.2824592590332 34.28087615966797 34.27932357788086]
#  [32.98784637451172 32.99045944213867 32.99309539794922 ...,
#   34.28463363647461 34.282989501953125 34.2813720703125]
#  [32.985504150390625 32.988067626953125 32.99067306518555 ...,
#   34.28689193725586 34.28520202636719 34.28352355957031]]

# %%
f = modeltools.hycom.io.ABFileArchv("/work/users/knutali/hycom/TP5a0.05/relax/010/relax.0000_016_00","r")
#print f._fields
fld=f.readfield("temp",5)
figure = matplotlib.pyplot.figure(figsize=(8,8))
ax=figure.add_subplot(111)
P=matplotlib.pyplot.pcolormesh(fld)
P.set_clim(-2,12)
matplotlib.pyplot.show()


#print fld
# Out:
# DEBUG:root:Endianness set to big
# pattern :  ^(.*)'(iversn)'[ =]*
# line    :  22    'iversn' = hycom version number x10
# match: <_sre.SRE_Match object at 0x7f45ee7dc608>
# pattern :  ^(.*)'(iexpt )'[ =]*
# line    :  10    'iexpt ' = experiment number x10
# match: <_sre.SRE_Match object at 0x7f45ee7dc608>
# pattern :  ^(.*)'(yrflag)'[ =]*
# line    :  1    'yrflag' = days in year flag
# match: <_sre.SRE_Match object at 0x7f45ee7dc608>
# pattern :  ^(.*)'(idm   )'[ =]*
# line    :  1350    'idm   ' = longitudinal array size
# match: <_sre.SRE_Match object at 0x7f45ee7dc608>
# pattern :  ^(.*)'(jdm   )'[ =]*
# line    :  1150    'jdm   ' = latitudinal  array size
# match: <_sre.SRE_Match object at 0x7f45ee7dc608>
# -1.99388158321 11.0421075821
